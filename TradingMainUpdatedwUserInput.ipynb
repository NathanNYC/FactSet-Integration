# %%
import pandas as pd 
import numpy as np
import csv

#=FDS("DRRX-US","FCS_EV(EV,CURRENT,0,,,,M)")
#=FDS("ICPT-US","FE_ESTIMATE(SALES,MEAN,ANN_ROLL,2020,0,,,'')")
#=FDS("AAPL-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL,+1,NOW,,,'')")
    
def tickerInput():
    again = "y"
    list1=[]
    while again == "y" or again == "yes":
        print("So far, you entered:",list1)
        getTicker=input("Enter a ticker:")
        list1.append(getTicker)
        try:
            again=input("Again?")
        except: print("Only enter y/n")
    return list1

def buildEVcodes(list1):
    list2=["=FDS(\"" + x for x in list1]
    list3=["-US\",\"FCS_EV(EV,CURRENT,0,,,,M)\")"]*len(list1)
    list4=[x+y for x,y in zip(list2,list3)]
    return list4

def buildSalescodes(list1):
    list2a=["=FDS(\"" + x for x in list1]
    list3a=["-US\",\"FE_ESTIMATE(SALES,MEAN,ANN_ROLL,2020,0,,,'')\")"]*len(list1)
    list4a=[a+b for a,b in zip(list2a,list3a)]
    return list4a

def buildEarningscodes(list1):
    list2b=["=FDS(\"" + x for x in list1]
    list3b=["-US\",\"FE_ESTIMATE(EPS,MEAN,QTR_ROLL,+1,NOW,,,'')\")"]*len(list1)
    list4b=[x+y for x,y in zip(list2b,list3b)]
    return list4b

def sendout(list1,list4,list4a,list4b): 
    out_frame=pd.DataFrame({"Tickers":list1,"EV":list4,"Sales":list4a,"Earnings":list4b})
    out_frame.to_csv ('C:/Users/nsw26/Desktop/Coding projects/trading_project/fit1.csv', index = False, header=True)
    print(out_frame)
    
def main():
    list1=tickerInput()
    list4=buildEVcodes(list1)
    list4a=buildSalescodes(list1)
    list4b=buildEarningscodes(list1)
    sendout(list1,list4,list4a,list4b)
    
    
if __name__=="__main__": main()
# Out:
# So far, you entered: []
# Enter a ticker:one
# Again?y
# So far, you entered: ['one']
# Enter a ticker:two
# Again?y
# So far, you entered: ['one', 'two']
# Enter a ticker:three
# Again?y
# So far, you entered: ['one', 'two', 'three']
# Enter a ticker:four
# Again?y
# So far, you entered: ['one', 'two', 'three', 'four']
# Enter a ticker:five
# Again?y
# So far, you entered: ['one', 'two', 'three', 'four', 'five']
# Enter a ticker:five
# Again?y
# So far, you entered: ['one', 'two', 'three', 'four', 'five', 'five']
# Enter a ticker:six
# Again?y
# So far, you entered: ['one', 'two', 'three', 'four', 'five', 'five', 'six']
# Enter a ticker:seven
# Again?y
# So far, you entered: ['one', 'two', 'three', 'four', 'five', 'five', 'six', 'seven']
# Enter a ticker:eight
# Again?y
# So far, you entered: ['one', 'two', 'three', 'four', 'five', 'five', 'six', 'seven', 'eight']
# Enter a ticker:nine
# Again?y
# So far, you entered: ['one', 'two', 'three', 'four', 'five', 'five', 'six', 'seven', 'eight', 'nine']
# Enter a ticker:ten
# Again?y
# So far, you entered: ['one', 'two', 'three', 'four', 'five', 'five', 'six', 'seven', 'eight', 'nine', 'ten']
# Enter a ticker:eleven
# Again?y
# So far, you entered: ['one', 'two', 'three', 'four', 'five', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'eleven']
# Enter a ticker:twelve
# Again?n
#                                                EV  \
# 0      =FDS("one-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 1      =FDS("two-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 2    =FDS("three-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 3     =FDS("four-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 4     =FDS("five-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 5     =FDS("five-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 6      =FDS("six-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 7    =FDS("seven-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 8    =FDS("eight-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 9     =FDS("nine-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 10     =FDS("ten-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 11  =FDS("eleven-US","FCS_EV(EV,CURRENT,0,,,,M)")
# 12  =FDS("twelve-US","FCS_EV(EV,CURRENT,0,,,,M)")
#
#                                              Earnings  \
# 0   =FDS("one-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL,+...
# 1   =FDS("two-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL,+...
# 2   =FDS("three-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL...
# 3   =FDS("four-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL,...
# 4   =FDS("five-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL,...
# 5   =FDS("five-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL,...
# 6   =FDS("six-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL,+...
# 7   =FDS("seven-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL...
# 8   =FDS("eight-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL...
# 9   =FDS("nine-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL,...
# 10  =FDS("ten-US","FE_ESTIMATE(EPS,MEAN,QTR_ROLL,+...
# 11  =FDS("eleven-US","FE_ESTIMATE(EPS,MEAN,QTR_ROL...
# 12  =FDS("twelve-US","FE_ESTIMATE(EPS,MEAN,QTR_ROL...
#
#                                                 Sales Tickers
# 0   =FDS("one-US","FE_ESTIMATE(SALES,MEAN,ANN_ROLL...     one
# 1   =FDS("two-US","FE_ESTIMATE(SALES,MEAN,ANN_ROLL...     two
# 2   =FDS("three-US","FE_ESTIMATE(SALES,MEAN,ANN_RO...   three
# 3   =FDS("four-US","FE_ESTIMATE(SALES,MEAN,ANN_ROL...    four
# 4   =FDS("five-US","FE_ESTIMATE(SALES,MEAN,ANN_ROL...    five
# 5   =FDS("five-US","FE_ESTIMATE(SALES,MEAN,ANN_ROL...    five
# 6   =FDS("six-US","FE_ESTIMATE(SALES,MEAN,ANN_ROLL...     six
# 7   =FDS("seven-US","FE_ESTIMATE(SALES,MEAN,ANN_RO...   seven
# 8   =FDS("eight-US","FE_ESTIMATE(SALES,MEAN,ANN_RO...   eight
# 9   =FDS("nine-US","FE_ESTIMATE(SALES,MEAN,ANN_ROL...    nine
# 10  =FDS("ten-US","FE_ESTIMATE(SALES,MEAN,ANN_ROLL...     ten
# 11  =FDS("eleven-US","FE_ESTIMATE(SALES,MEAN,ANN_R...  eleven
# 12  =FDS("twelve-US","FE_ESTIMATE(SALES,MEAN,ANN_R...  twelve
